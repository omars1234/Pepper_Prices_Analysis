# %% [markdown]
# # *02_Correlation*

# %%
from Constants import PATH
PATH=PATH
import os
os.chdir(PATH)
from utils_packeges import *
# Out:
#         <script>
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.4.0.min"</script>

# %%
from utils import laod_cleaned_data

df,numerical_cols,categorical_cols,boolean_cols,date_cols=laod_cleaned_data()

print(f"numerical_cols : \n{numerical_cols}")
print("--------------------------------------------------")
print(f"categorical_cols : \n{categorical_cols}")
print("--------------------------------------------------")
print(f"boolean_cols : \n{boolean_cols}")
print("--------------------------------------------------")
print(f"date_cols : \n{date_cols}")
# Out:
# numerical_cols :
# ['vietnam_season', 'price', 'total_volume', 'brazil', 'india', 'vietnam', 'indonesia', 'china', 'jordan_max_price', 'jordan_min_price', 'demand', 'supply', 'month', 'year', 'DayOfMonth']
# --------------------------------------------------
# categorical_cols :
# ['p_color']
# --------------------------------------------------
# boolean_cols :
# ['brazil_season', 'indonesia_season', 'india_season', 'china_season']
# --------------------------------------------------
# date_cols :
# ['week_start_dt', 'week_end_dt']

# %% [markdown]
# ### *Comprehensive correlation matrix analysis with confidence intervals ,and creating advanced correlation visualizations*

# %%
from utils import (fishers_z_transform,
                   inverse_fishers_z,
                   correlation_confidence_interval,comprehensive_correlation_matrix_analysis,create_advanced_correlation_visualizations,
                   hierarchical_clustering_correlations,bootstrap_correlation_confidence_intervals,
                   power_analysis_correlation,practical_correlation_reporting_guide)

# %%
print("\n EXECUTING ADVANCED CORRELATION ANALYSIS")
print("=" * 100)
# Out:
#  EXECUTING ADVANCED CORRELATION ANALYSIS
# ====================================================================================================

# %% [markdown]
# ### *Step 1: Comprehensive correlation matrix analysis*

# %%
print("\n Step 1: Comprehensive correlation matrix analysis with confidence intervals")
comprehensive_analysis = comprehensive_correlation_matrix_analysis(df, numerical_cols)
# Out:
#  Step 1: Comprehensive correlation matrix analysis with confidence intervals
#
# ======================================================================
# COMPREHENSIVE CORRELATION MATRIX ANALYSIS
# ======================================================================
# Calculating correlations with 95% confidence intervals:
# ------------------------------------------------------------
# vietnam_season ↔ price:
#   r =  -0.133 [-0.188, -0.078], p =  0.0000, n = 1215
# vietnam_season ↔ total_volume:
#   r =   0.105 [ 0.049,  0.160], p =  0.0003, n = 1215
# vietnam_season ↔ brazil:
#   r =   0.129 [ 0.073,  0.184], p =  0.0000, n = 1215
# vietnam_season ↔ india:
#   r =  -0.173 [-0.227, -0.118], p =  0.0000, n = 1215
# vietnam_season ↔ vietnam:
#   r =   0.318 [ 0.267,  0.368], p =  0.0000, n = 1215
# vietnam_season ↔ indonesia:
#   r =  -0.612 [-0.646, -0.575], p =  0.0000, n = 1215
# vietnam_season ↔ china:
#   r =  -0.210 [-0.263, -0.155], p =  0.0000, n = 1215
# vietnam_season ↔ jordan_max_price:
#   r =  -0.175 [-0.229, -0.119], p =  0.0000, n = 1215
# vietnam_season ↔ jordan_min_price:
#   r =  -0.139 [-0.194, -0.084], p =  0.0000, n = 1215
# vietnam_season ↔ demand:
#   r =   0.074 [ 0.018,  0.130], p =  0.0094, n = 1215
# vietnam_season ↔ supply:
#   r =   0.030 [-0.027,  0.086], p =  0.3019, n = 1215
# vietnam_season ↔ month:
#   r =  -0.378 [-0.425, -0.328], p =  0.0000, n = 1215
# vietnam_season ↔ year:
#   r =  -0.004 [-0.060,  0.052], p =  0.8933, n = 1215
# vietnam_season ↔ DayOfMonth:
#   r =  -0.004 [-0.060,  0.052], p =  0.8889, n = 1215
# price ↔ total_volume:
#   r =  -0.144 [-0.199, -0.089], p =  0.0000, n = 1215
# price ↔ brazil:
#   r =   0.243 [ 0.190,  0.296], p =  0.0000, n = 1215
# price ↔ india:
#   r =   0.140 [ 0.084,  0.195], p =  0.0000, n = 1215
# price ↔ vietnam:
#   r =  -0.365 [-0.413, -0.315], p =  0.0000, n = 1215
# price ↔ indonesia:
#   r =   0.290 [ 0.238,  0.341], p =  0.0000, n = 1215
# price ↔ china:
#   r =   0.167 [ 0.111,  0.221], p =  0.0000, n = 1215
# price ↔ jordan_max_price:
#   r =   0.965 [ 0.961,  0.969], p =  0.0000, n = 1215
# price ↔ jordan_min_price:
#   r =   0.968 [ 0.964,  0.971], p =  0.0000, n = 1215
# price ↔ demand:
#   r =   0.333 [ 0.283,  0.383], p =  0.0000, n = 1215
# price ↔ supply:
#   r =   0.112 [ 0.056,  0.167], p =  0.0001, n = 1215
# price ↔ month:
#   r =  -0.022 [-0.078,  0.034], p =  0.4448, n = 1215
# price ↔ year:
#   r =  -0.004 [-0.060,  0.052], p =  0.8900, n = 1215
# price ↔ DayOfMonth:
#   r =  -0.004 [-0.060,  0.052], p =  0.8912, n = 1215
# total_volume ↔ brazil:
#   r =   0.184 [ 0.129,  0.238], p =  0.0000, n = 1215
# total_volume ↔ india:
#   r =  -0.336 [-0.385, -0.285], p =  0.0000, n = 1215
# total_volume ↔ vietnam:
#   r =   0.743 [ 0.717,  0.767], p =  0.0000, n = 1215
# total_volume ↔ indonesia:
#   r =   0.108 [ 0.052,  0.163], p =  0.0002, n = 1215
# total_volume ↔ china:
#   r =   0.178 [ 0.123,  0.232], p =  0.0000, n = 1215
# total_volume ↔ jordan_max_price:
#   r =  -0.155 [-0.209, -0.099], p =  0.0000, n = 1215
# total_volume ↔ jordan_min_price:
#   r =  -0.142 [-0.196, -0.086], p =  0.0000, n = 1215
# total_volume ↔ demand:
#   r =   0.043 [-0.013,  0.099], p =  0.1331, n = 1215
# total_volume ↔ supply:
#   r =   0.344 [ 0.294,  0.393], p =  0.0000, n = 1215
# total_volume ↔ month:
#   r =  -0.306 [-0.356, -0.254], p =  0.0000, n = 1215
# total_volume ↔ year:
#   r =   0.458 [ 0.413,  0.502], p =  0.0000, n = 1215
# total_volume ↔ DayOfMonth:
#   r =  -0.031 [-0.087,  0.026], p =  0.2867, n = 1215
# brazil ↔ india:
#   r =  -0.417 [-0.463, -0.370], p =  0.0000, n = 1215
# brazil ↔ vietnam:
#   r =  -0.381 [-0.428, -0.332], p =  0.0000, n = 1215
# brazil ↔ indonesia:
#   r =   0.371 [ 0.321,  0.418], p =  0.0000, n = 1215
# brazil ↔ china:
#   r =   0.108 [ 0.052,  0.163], p =  0.0002, n = 1215
# brazil ↔ jordan_max_price:
#   r =   0.209 [ 0.155,  0.262], p =  0.0000, n = 1215
# brazil ↔ jordan_min_price:
#   r =   0.208 [ 0.154,  0.261], p =  0.0000, n = 1215
# brazil ↔ demand:
#   r =  -0.003 [-0.059,  0.053], p =  0.9206, n = 1215
# brazil ↔ supply:
#   r =   0.018 [-0.038,  0.074], p =  0.5338, n = 1215
# brazil ↔ month:
#   r =  -0.312 [-0.362, -0.260], p =  0.0000, n = 1215
# brazil ↔ year:
#   r =  -0.017 [-0.074,  0.039], p =  0.5431, n = 1215
# brazil ↔ DayOfMonth:
#   r =   0.001 [-0.055,  0.057], p =  0.9711, n = 1215
# india ↔ vietnam:
#   r =  -0.104 [-0.159, -0.048], p =  0.0003, n = 1215
# india ↔ indonesia:
#   r =  -0.225 [-0.278, -0.171], p =  0.0000, n = 1215
# india ↔ china:
#   r =  -0.173 [-0.227, -0.118], p =  0.0000, n = 1215
# india ↔ jordan_max_price:
#   r =   0.178 [ 0.123,  0.232], p =  0.0000, n = 1215
# india ↔ jordan_min_price:
#   r =   0.162 [ 0.107,  0.216], p =  0.0000, n = 1215
# india ↔ demand:
#   r =  -0.037 [-0.093,  0.019], p =  0.1957, n = 1215
# india ↔ supply:
#   r =  -0.226 [-0.278, -0.172], p =  0.0000, n = 1215
# india ↔ month:
#   r =   0.340 [ 0.289,  0.389], p =  0.0000, n = 1215
# india ↔ year:
#   r =  -0.367 [-0.414, -0.317], p =  0.0000, n = 1215
# india ↔ DayOfMonth:
#   r =   0.007 [-0.049,  0.063], p =  0.8135, n = 1215
# vietnam ↔ indonesia:
#   r =  -0.482 [-0.524, -0.437], p =  0.0000, n = 1215
# vietnam ↔ china:
#   r =  -0.105 [-0.161, -0.049], p =  0.0002, n = 1215
# vietnam ↔ jordan_max_price:
#   r =  -0.369 [-0.417, -0.319], p =  0.0000, n = 1215
# vietnam ↔ jordan_min_price:
#   r =  -0.342 [-0.391, -0.292], p =  0.0000, n = 1215
# vietnam ↔ demand:
#   r =   0.077 [ 0.021,  0.133], p =  0.0073, n = 1215
# vietnam ↔ supply:
#   r =   0.294 [ 0.242,  0.345], p =  0.0000, n = 1215
# vietnam ↔ month:
#   r =  -0.207 [-0.260, -0.153], p =  0.0000, n = 1215
# vietnam ↔ year:
#   r =   0.333 [ 0.282,  0.382], p =  0.0000, n = 1215
# vietnam ↔ DayOfMonth:
#   r =  -0.027 [-0.084,  0.029], p =  0.3389, n = 1215
# indonesia ↔ china:
#   r =   0.444 [ 0.398,  0.488], p =  0.0000, n = 1215
# indonesia ↔ jordan_max_price:
#   r =   0.303 [ 0.251,  0.354], p =  0.0000, n = 1215
# indonesia ↔ jordan_min_price:
#   r =   0.271 [ 0.219,  0.323], p =  0.0000, n = 1215
# indonesia ↔ demand:
#   r =  -0.076 [-0.132, -0.020], p =  0.0080, n = 1215
# indonesia ↔ supply:
#   r =   0.010 [-0.046,  0.067], p =  0.7182, n = 1215
# indonesia ↔ month:
#   r =   0.111 [ 0.055,  0.166], p =  0.0001, n = 1215
# indonesia ↔ year:
#   r =   0.176 [ 0.121,  0.230], p =  0.0000, n = 1215
# indonesia ↔ DayOfMonth:
#   r =   0.002 [-0.055,  0.058], p =  0.9561, n = 1215
# china ↔ jordan_max_price:
#   r =   0.182 [ 0.127,  0.235], p =  0.0000, n = 1215
# china ↔ jordan_min_price:
#   r =   0.173 [ 0.117,  0.227], p =  0.0000, n = 1215
# china ↔ demand:
#   r =  -0.093 [-0.148, -0.037], p =  0.0012, n = 1215
# china ↔ supply:
#   r =   0.119 [ 0.063,  0.174], p =  0.0000, n = 1215
# china ↔ month:
#   r =  -0.013 [-0.070,  0.043], p =  0.6387, n = 1215
# china ↔ year:
#   r =   0.495 [ 0.452,  0.536], p =  0.0000, n = 1215
# china ↔ DayOfMonth:
#   r =  -0.005 [-0.061,  0.052], p =  0.8739, n = 1215
# jordan_max_price ↔ jordan_min_price:
#   r =   0.981 [ 0.979,  0.983], p =  0.0000, n = 1215
# jordan_max_price ↔ demand:
#   r =   0.306 [ 0.254,  0.356], p =  0.0000, n = 1215
# jordan_max_price ↔ supply:
#   r =   0.111 [ 0.055,  0.166], p =  0.0001, n = 1215
# jordan_max_price ↔ month:
#   r =   0.015 [-0.042,  0.071], p =  0.6120, n = 1215
# jordan_max_price ↔ year:
#   r =   0.005 [-0.052,  0.061], p =  0.8695, n = 1215
# jordan_max_price ↔ DayOfMonth:
#   r =  -0.005 [-0.061,  0.051], p =  0.8588, n = 1215
# jordan_min_price ↔ demand:
#   r =   0.330 [ 0.279,  0.379], p =  0.0000, n = 1215
# jordan_min_price ↔ supply:
#   r =   0.127 [ 0.071,  0.182], p =  0.0000, n = 1215
# jordan_min_price ↔ month:
#   r =  -0.009 [-0.066,  0.047], p =  0.7458, n = 1215
# jordan_min_price ↔ year:
#   r =  -0.003 [-0.059,  0.053], p =  0.9172, n = 1215
# jordan_min_price ↔ DayOfMonth:
#   r =  -0.003 [-0.059,  0.053], p =  0.9103, n = 1215
# demand ↔ supply:
#   r =   0.404 [ 0.356,  0.450], p =  0.0000, n = 1215
# demand ↔ month:
#   r =  -0.083 [-0.139, -0.027], p =  0.0038, n = 1215
# demand ↔ year:
#   r =  -0.057 [-0.113, -0.001], p =  0.0471, n = 1215
# demand ↔ DayOfMonth:
#   r =   0.007 [-0.049,  0.063], p =  0.8061, n = 1215
# supply ↔ month:
#   r =  -0.019 [-0.075,  0.038], p =  0.5192, n = 1215
# supply ↔ year:
#   r =   0.483 [ 0.439,  0.525], p =  0.0000, n = 1215
# supply ↔ DayOfMonth:
#   r =   0.009 [-0.047,  0.066], p =  0.7414, n = 1215
# month ↔ year:
#   r =  -0.077 [-0.133, -0.021], p =  0.0070, n = 1215
# month ↔ DayOfMonth:
#   r =   0.025 [-0.031,  0.081], p =  0.3828, n = 1215
# year ↔ DayOfMonth:
#   r =   0.000 [-0.056,  0.057], p =  0.9894, n = 1215
#
# Correlation Matrix:
# --------------------
#                   vietnam_season  price  total_volume  brazil  india  vietnam  \
# vietnam_season             1.000 -0.133         0.105   0.129 -0.173    0.318
# price                     -0.133  1.000        -0.144   0.243  0.140   -0.365
# total_volume               0.105 -0.144         1.000   0.184 -0.336    0.743
# brazil                     0.129  0.243         0.184   1.000 -0.417   -0.381
# india                     -0.173  0.140        -0.336  -0.417  1.000   -0.104
# vietnam                    0.318 -0.365         0.743  -0.381 -0.104    1.000
# indonesia                 -0.612  0.290         0.108   0.371 -0.225   -0.482
# china                     -0.210  0.167         0.178   0.108 -0.173   -0.105
# jordan_max_price          -0.175  0.965        -0.155   0.209  0.178   -0.369
# jordan_min_price          -0.139  0.968        -0.142   0.208  0.162   -0.342
# demand                     0.074  0.333         0.043  -0.003 -0.037    0.077
# supply                     0.030  0.112         0.344   0.018 -0.226    0.294
# month                     -0.378 -0.022        -0.306  -0.312  0.340   -0.207
# year                      -0.004 -0.004         0.458  -0.017 -0.367    0.333
# DayOfMonth                -0.004 -0.004        -0.031   0.001  0.007   -0.027
#
#                   indonesia  china  jordan_max_price  jordan_min_price  \
# vietnam_season       -0.612 -0.210            -0.175            -0.139
# price                 0.290  0.167             0.965             0.968
# total_volume          0.108  0.178            -0.155            -0.142
# brazil                0.371  0.108             0.209             0.208
# india                -0.225 -0.173             0.178             0.162
# vietnam              -0.482 -0.105            -0.369            -0.342
# indonesia             1.000  0.444             0.303             0.271
# china                 0.444  1.000             0.182             0.173
# jordan_max_price      0.303  0.182             1.000             0.981
# jordan_min_price      0.271  0.173             0.981             1.000
# demand               -0.076 -0.093             0.306             0.330
# supply                0.010  0.119             0.111             0.127
# month                 0.111 -0.013             0.015            -0.009
# year                  0.176  0.495             0.005            -0.003
# DayOfMonth            0.002 -0.005            -0.005            -0.003
#
#                   demand  supply  month   year  DayOfMonth
# vietnam_season     0.074   0.030 -0.378 -0.004      -0.004
# price              0.333   0.112 -0.022 -0.004      -0.004
# total_volume       0.043   0.344 -0.306  0.458      -0.031
# brazil            -0.003   0.018 -0.312 -0.017       0.001
# india             -0.037  -0.226  0.340 -0.367       0.007
# vietnam            0.077   0.294 -0.207  0.333      -0.027
# indonesia         -0.076   0.010  0.111  0.176       0.002
# china             -0.093   0.119 -0.013  0.495      -0.005
# jordan_max_price   0.306   0.111  0.015  0.005      -0.005
# jordan_min_price   0.330   0.127 -0.009 -0.003      -0.003
# demand             1.000   0.404 -0.083 -0.057       0.007
# supply             0.404   1.000 -0.019  0.483       0.009
# month             -0.083  -0.019  1.000 -0.077       0.025
# year              -0.057   0.483 -0.077  1.000       0.000
# DayOfMonth         0.007   0.009  0.025  0.000       1.000
#
# Multiple Comparisons Correction:
# -----------------------------------
# Bonferroni               : 68 significant out of 105
# Holm                     : 69 significant out of 105
# FDR (Benjamini-Hochberg) : 74 significant out of 105
# FDR (Benjamini-Yekutieli): 70 significant out of 105

# %% [markdown]
# ### *Step 2: Advanced visualizations*

# %%
print("\n Step 2: Creating advanced correlation visualizations")
create_advanced_correlation_visualizations(comprehensive_analysis, numerical_cols)
# Out:
#  Step 2: Creating advanced correlation visualizations
#
# ======================================================================
# ADVANCED CORRELATION VISUALIZATIONS
# ======================================================================

# %% [markdown]
# ### *Step 3: Hierarchical clustering*

# %%
print("\n Step 3: Hierarchical clustering of correlation matrix")
clustering_results = hierarchical_clustering_correlations(comprehensive_analysis['correlation_matrix'], numerical_cols)
# Out:
#  Step 3: Hierarchical clustering of correlation matrix
#
# ======================================================================
# HIERARCHICAL CLUSTERING OF CORRELATION MATRIX
# ======================================================================
# Variable clustering at different cut levels:
# ---------------------------------------------
#
# 2 clusters:
#   Cluster 1: ['price', 'jordan_max_price', 'jordan_min_price']
#   Cluster 2: ['vietnam_season', 'total_volume', 'brazil', 'india', 'vietnam', 'indonesia', 'china', 'demand', 'supply', 'month', 'year', 'DayOfMonth']
#
# 3 clusters:
#   Cluster 1: ['price', 'jordan_max_price', 'jordan_min_price']
#   Cluster 2: ['vietnam_season', 'brazil', 'india', 'indonesia', 'month']
#   Cluster 3: ['total_volume', 'vietnam', 'china', 'demand', 'supply', 'year', 'DayOfMonth']
#
# 4 clusters:
#   Cluster 1: ['price', 'jordan_max_price', 'jordan_min_price']
#   Cluster 2: ['vietnam_season', 'brazil', 'india', 'indonesia', 'month']
#   Cluster 3: ['total_volume', 'vietnam', 'china', 'demand', 'supply', 'year']
#   Cluster 4: ['DayOfMonth']

# %% [markdown]
# ### *Step 4: Bootstrap confidence intervals for a key correlation*

# %%
print("\n Step 4: Bootstrap confidence intervals demonstration")
bootstrap_results = bootstrap_correlation_confidence_intervals(df, 'total_volume', 'price', n_bootstrap=1000)
# Out:
#  Step 4: Bootstrap confidence intervals demonstration
#
# ============================================================
# BOOTSTRAP CONFIDENCE INTERVALS: total_volume vs price
# ============================================================
# Original sample size: 1215
# Bootstrap samples: 1000
# Confidence level: 95%
#
# Results:
# ----------
# Original correlation: -0.1443
# Bootstrap mean: -0.1446
# Bootstrap bias: -0.0003
# Bootstrap std: 0.0274
#
# Confidence Intervals:
# ----------------------
# Bootstrap CI:   [-0.1963, -0.0896]
# Fisher's Z CI:  [-0.1990, -0.0888]

# %% [markdown]
# ### *Step 5: Power analysis*

# %%
print("\n Step 5: Power analysis for correlation studies")
power_analysis_results = power_analysis_correlation()
# Out:
#  Step 5: Power analysis for correlation studies
#
# ======================================================================
# POWER ANALYSIS FOR CORRELATION STUDIES
# ======================================================================
# Cohen's guidelines for correlation effect sizes:
# Small effect:    |r| = 0.10
# Medium effect:   |r| = 0.30
# Large effect:    |r| = 0.50
#
# Power analysis parameters:
# Alpha level: 0.05
# Desired power: 0.8
#
# Sample size requirements for 80% power:
# ---------------------------------------------
# r = 0.1: n =  783
# r = 0.2: n =  194
# r = 0.3: n =   85
# r = 0.4: n =   47
# r = 0.5: n =   30

# %% [markdown]
# ### *Step 6: Final report*

# %%
print("\n Step 6: Final report")
summary_table = practical_correlation_reporting_guide(comprehensive_analysis)
# Out:
#  Step 6: Final report
#
# ======================================================================
# PRACTICAL GUIDE FOR REPORTING CORRELATIONS
# ======================================================================
# Essential elements for reporting correlations:
# ---------------------------------------------
# 1. Correlation coefficient type (Pearson/Spearman)
# 2. Sample size and degrees of freedom
# 3. Confidence intervals
# 4. Statistical significance
# 5. Effect size interpretation
# 6. Multiple comparisons correction (if applicable)
#
# Example reporting formats:
# ---------------------------
#
# Example 1:
# Standard format:
#   'There was a small negative correlation between
#    vietnam season and price, r(1213) = -0.133,
#    95% CI [-0.188, -0.078], p < .001.'
# APA format:
#   'Vietnam Season and price were significantly correlated,
#    r = -0.13, p < .001, 95% CI [-0.19, -0.08].'
#
# Example 2:
# Standard format:
#   'There was a small positive correlation between
#    vietnam season and total volume, r(1213) = 0.105,
#    95% CI [0.049, 0.160], p < .001.'
# APA format:
#   'Vietnam Season and total volume were significantly correlated,
#    r = 0.10, p < .001, 95% CI [0.05, 0.16].'
#
# Example 3:
# Standard format:
#   'There was a small positive correlation between
#    vietnam season and brazil, r(1213) = 0.129,
#    95% CI [0.073, 0.184], p < .001.'
# APA format:
#   'Vietnam Season and brazil were significantly correlated,
#    r = 0.13, p < .001, 95% CI [0.07, 0.18].'
#
# ==================================================
# SUMMARY TABLE FOR ALL CORRELATIONS
# ==================================================
#                           Variables      r           95% CI p-value    n Significant
#              vietnam_season ↔ price -0.133 [-0.188, -0.078]  0.0000 1215         Yes
#       vietnam_season ↔ total_volume  0.105   [0.049, 0.160]  0.0003 1215         Yes
#             vietnam_season ↔ brazil  0.129   [0.073, 0.184]  0.0000 1215         Yes
#              vietnam_season ↔ india -0.173 [-0.227, -0.118]  0.0000 1215         Yes
#            vietnam_season ↔ vietnam  0.318   [0.267, 0.368]  0.0000 1215         Yes
#          vietnam_season ↔ indonesia -0.612 [-0.646, -0.575]  0.0000 1215         Yes
#              vietnam_season ↔ china -0.210 [-0.263, -0.155]  0.0000 1215         Yes
#   vietnam_season ↔ jordan_max_price -0.175 [-0.229, -0.119]  0.0000 1215         Yes
#   vietnam_season ↔ jordan_min_price -0.139 [-0.194, -0.084]  0.0000 1215         Yes
#             vietnam_season ↔ demand  0.074   [0.018, 0.130]  0.0094 1215         Yes
#             vietnam_season ↔ supply  0.030  [-0.027, 0.086]  0.3019 1215          No
#              vietnam_season ↔ month -0.378 [-0.425, -0.328]  0.0000 1215         Yes
#               vietnam_season ↔ year -0.004  [-0.060, 0.052]  0.8933 1215          No
#         vietnam_season ↔ DayOfMonth -0.004  [-0.060, 0.052]  0.8889 1215          No
#                price ↔ total_volume -0.144 [-0.199, -0.089]  0.0000 1215         Yes
#                      price ↔ brazil  0.243   [0.190, 0.296]  0.0000 1215         Yes
#                       price ↔ india  0.140   [0.084, 0.195]  0.0000 1215         Yes
#                     price ↔ vietnam -0.365 [-0.413, -0.315]  0.0000 1215         Yes
#                   price ↔ indonesia  0.290   [0.238, 0.341]  0.0000 1215         Yes
#                       price ↔ china  0.167   [0.111, 0.221]  0.0000 1215         Yes
#            price ↔ jordan_max_price  0.965   [0.961, 0.969]  0.0000 1215         Yes
#            price ↔ jordan_min_price  0.968   [0.964, 0.971]  0.0000 1215         Yes
#                      price ↔ demand  0.333   [0.283, 0.383]  0.0000 1215         Yes
#                      price ↔ supply  0.112   [0.056, 0.167]  0.0001 1215         Yes
#                       price ↔ month -0.022  [-0.078, 0.034]  0.4448 1215          No
#                        price ↔ year -0.004  [-0.060, 0.052]  0.8900 1215          No
#                  price ↔ DayOfMonth -0.004  [-0.060, 0.052]  0.8912 1215          No
#               total_volume ↔ brazil  0.184   [0.129, 0.238]  0.0000 1215         Yes
#                total_volume ↔ india -0.336 [-0.385, -0.285]  0.0000 1215         Yes
#              total_volume ↔ vietnam  0.743   [0.717, 0.767]  0.0000 1215         Yes
#            total_volume ↔ indonesia  0.108   [0.052, 0.163]  0.0002 1215         Yes
#                total_volume ↔ china  0.178   [0.123, 0.232]  0.0000 1215         Yes
#     total_volume ↔ jordan_max_price -0.155 [-0.209, -0.099]  0.0000 1215         Yes
#     total_volume ↔ jordan_min_price -0.142 [-0.196, -0.086]  0.0000 1215         Yes
#               total_volume ↔ demand  0.043  [-0.013, 0.099]  0.1331 1215          No
#               total_volume ↔ supply  0.344   [0.294, 0.393]  0.0000 1215         Yes
#                total_volume ↔ month -0.306 [-0.356, -0.254]  0.0000 1215         Yes
#                 total_volume ↔ year  0.458   [0.413, 0.502]  0.0000 1215         Yes
#           total_volume ↔ DayOfMonth -0.031  [-0.087, 0.026]  0.2867 1215          No
#                      brazil ↔ india -0.417 [-0.463, -0.370]  0.0000 1215         Yes
#                    brazil ↔ vietnam -0.381 [-0.428, -0.332]  0.0000 1215         Yes
#                  brazil ↔ indonesia  0.371   [0.321, 0.418]  0.0000 1215         Yes
#                      brazil ↔ china  0.108   [0.052, 0.163]  0.0002 1215         Yes
#           brazil ↔ jordan_max_price  0.209   [0.155, 0.262]  0.0000 1215         Yes
#           brazil ↔ jordan_min_price  0.208   [0.154, 0.261]  0.0000 1215         Yes
#                     brazil ↔ demand -0.003  [-0.059, 0.053]  0.9206 1215          No
#                     brazil ↔ supply  0.018  [-0.038, 0.074]  0.5338 1215          No
#                      brazil ↔ month -0.312 [-0.362, -0.260]  0.0000 1215         Yes
#                       brazil ↔ year -0.017  [-0.074, 0.039]  0.5431 1215          No
#                 brazil ↔ DayOfMonth  0.001  [-0.055, 0.057]  0.9711 1215          No
#                     india ↔ vietnam -0.104 [-0.159, -0.048]  0.0003 1215         Yes
#                   india ↔ indonesia -0.225 [-0.278, -0.171]  0.0000 1215         Yes
#                       india ↔ china -0.173 [-0.227, -0.118]  0.0000 1215         Yes
#            india ↔ jordan_max_price  0.178   [0.123, 0.232]  0.0000 1215         Yes
#            india ↔ jordan_min_price  0.162   [0.107, 0.216]  0.0000 1215         Yes
#                      india ↔ demand -0.037  [-0.093, 0.019]  0.1957 1215          No
#                      india ↔ supply -0.226 [-0.278, -0.172]  0.0000 1215         Yes
#                       india ↔ month  0.340   [0.289, 0.389]  0.0000 1215         Yes
#                        india ↔ year -0.367 [-0.414, -0.317]  0.0000 1215         Yes
#                  india ↔ DayOfMonth  0.007  [-0.049, 0.063]  0.8135 1215          No
#                 vietnam ↔ indonesia -0.482 [-0.524, -0.437]  0.0000 1215         Yes
#                     vietnam ↔ china -0.105 [-0.161, -0.049]  0.0002 1215         Yes
#          vietnam ↔ jordan_max_price -0.369 [-0.417, -0.319]  0.0000 1215         Yes
#          vietnam ↔ jordan_min_price -0.342 [-0.391, -0.292]  0.0000 1215         Yes
#                    vietnam ↔ demand  0.077   [0.021, 0.133]  0.0073 1215         Yes
#                    vietnam ↔ supply  0.294   [0.242, 0.345]  0.0000 1215         Yes
#                     vietnam ↔ month -0.207 [-0.260, -0.153]  0.0000 1215         Yes
#                      vietnam ↔ year  0.333   [0.282, 0.382]  0.0000 1215         Yes
#                vietnam ↔ DayOfMonth -0.027  [-0.084, 0.029]  0.3389 1215          No
#                   indonesia ↔ china  0.444   [0.398, 0.488]  0.0000 1215         Yes
#        indonesia ↔ jordan_max_price  0.303   [0.251, 0.354]  0.0000 1215         Yes
#        indonesia ↔ jordan_min_price  0.271   [0.219, 0.323]  0.0000 1215         Yes
#                  indonesia ↔ demand -0.076 [-0.132, -0.020]  0.0080 1215         Yes
#                  indonesia ↔ supply  0.010  [-0.046, 0.067]  0.7182 1215          No
#                   indonesia ↔ month  0.111   [0.055, 0.166]  0.0001 1215         Yes
#                    indonesia ↔ year  0.176   [0.121, 0.230]  0.0000 1215         Yes
#              indonesia ↔ DayOfMonth  0.002  [-0.055, 0.058]  0.9561 1215          No
#            china ↔ jordan_max_price  0.182   [0.127, 0.235]  0.0000 1215         Yes
#            china ↔ jordan_min_price  0.173   [0.117, 0.227]  0.0000 1215         Yes
#                      china ↔ demand -0.093 [-0.148, -0.037]  0.0012 1215         Yes
#                      china ↔ supply  0.119   [0.063, 0.174]  0.0000 1215         Yes
#                       china ↔ month -0.013  [-0.070, 0.043]  0.6387 1215          No
#                        china ↔ year  0.495   [0.452, 0.536]  0.0000 1215         Yes
#                  china ↔ DayOfMonth -0.005  [-0.061, 0.052]  0.8739 1215          No
# jordan_max_price ↔ jordan_min_price  0.981   [0.979, 0.983]  0.0000 1215         Yes
#           jordan_max_price ↔ demand  0.306   [0.254, 0.356]  0.0000 1215         Yes
#           jordan_max_price ↔ supply  0.111   [0.055, 0.166]  0.0001 1215         Yes
#            jordan_max_price ↔ month  0.015  [-0.042, 0.071]  0.6120 1215          No
#             jordan_max_price ↔ year  0.005  [-0.052, 0.061]  0.8695 1215          No
#       jordan_max_price ↔ DayOfMonth -0.005  [-0.061, 0.051]  0.8588 1215          No
#           jordan_min_price ↔ demand  0.330   [0.279, 0.379]  0.0000 1215         Yes
#           jordan_min_price ↔ supply  0.127   [0.071, 0.182]  0.0000 1215         Yes
#            jordan_min_price ↔ month -0.009  [-0.066, 0.047]  0.7458 1215          No
#             jordan_min_price ↔ year -0.003  [-0.059, 0.053]  0.9172 1215          No
#       jordan_min_price ↔ DayOfMonth -0.003  [-0.059, 0.053]  0.9103 1215          No
#                     demand ↔ supply  0.404   [0.356, 0.450]  0.0000 1215         Yes
#                      demand ↔ month -0.083 [-0.139, -0.027]  0.0038 1215         Yes
#                       demand ↔ year -0.057 [-0.113, -0.001]  0.0471 1215         Yes
#                 demand ↔ DayOfMonth  0.007  [-0.049, 0.063]  0.8061 1215          No
#                      supply ↔ month -0.019  [-0.075, 0.038]  0.5192 1215          No
#                       supply ↔ year  0.483   [0.439, 0.525]  0.0000 1215         Yes
#                 supply ↔ DayOfMonth  0.009  [-0.047, 0.066]  0.7414 1215          No
#                        month ↔ year -0.077 [-0.133, -0.021]  0.0070 1215         Yes
#                  month ↔ DayOfMonth  0.025  [-0.031, 0.081]  0.3828 1215          No
#                   year ↔ DayOfMonth  0.000  [-0.056, 0.057]  0.9894 1215          No
#
# Multiple comparisons correction impact:
# ----------------------------------------
# Uncorrected significant: 75/105
# Bonferroni significant:  68/105
# FDR (BH) significant:    74/105
